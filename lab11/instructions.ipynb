# %% [markdown]
# ## 🧬 LLM × Evolutionary Algorithms
#
# ### Learning objectives
# - Call an LLM (Gemini) from Python and parse the code it returns.
# - Use an LLM to generate metaheuristics and benchmark them on a standard test function.
# - Iterate on those algorithms with simple evolutionary operators.
#
# ### 1. Environment setup
# - Sign in to [Google AI Studio](https://aistudio.google.com/api-keys) and generate an API key.
# - We use Gemini for its generous free tier (~1500 requests/day).

# %%
# ! pip install google-genai

# %%
from google import genai
import os

MODEL = "gemini-2.0-flash-preview"
client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

# Smoke test
print(client.models.generate_content(model=MODEL, contents=["Hello, world!"]).text)

# %% [markdown]
# ### 2. Generating metaheuristics with an LLM
#
# LLMs can write Python, so we can ask them to write *optimization algorithms*. The workflow is simple: prompt the model with a function signature, parse the code from its response, and run it on a benchmark.
#
# We'll need a small utility to extract a function from a Markdown code block, validate it, and load it into the current namespace:

# %%
import ast
import re
from typing import Any, Callable


class FunctionParser:
    """Extracts a Python function from an LLM response and loads it as a callable.

    LLMs typically return code wrapped in a Markdown ```python ... ``` block,
    often surrounded by explanatory prose. This helper isolates the code,
    checks it parses as valid Python, executes it in a fresh namespace, and
    returns the named function so it can be called like any other callable.
    """

    @staticmethod
    def parse(model_response: str, function_name: str) -> Callable | None:
        """Parse `model_response` and return the function named `function_name`.

        Returns None if no code block is found or if the code is syntactically
        invalid. Otherwise the extracted code is executed and the requested
        function is looked up in the resulting namespace.
        """
        function_str = FunctionParser.extract_code(model_response)
        if not function_str or not FunctionParser.validate_function_syntax(function_str):
            return None
        namespace: dict[str, Any] = {}
        # WARNING: exec runs arbitrary model output. In production this MUST
        # happen inside a sandbox (subprocess, container, restricted runtime).
        exec(function_str, namespace)
        return namespace[function_name]

    @staticmethod
    def validate_function_syntax(function_str: str) -> bool:
        """Return True iff `function_str` parses as valid Python (AST check only).

        This catches malformed code before we exec it, but does not guarantee
        the code is safe or semantically correct.
        """
        try:
            ast.parse(function_str)
            return True
        except SyntaxError:
            return False

    @staticmethod
    def extract_code(text: str) -> str | None:
        """Pull the first ```python ... ``` block out of an LLM response.

        Returns the inner code as a string, or None if no fenced Python block
        is present.
        """
        match = re.search(r"```python\s*(.*?)\s*```", text, re.DOTALL)
        return match.group(1) if match else None

# %% [markdown]
# Now ask the LLM to invent a metaheuristic. We pin the function signature so the response is directly executable:

# %%
PROMPT_METAHEURISTIC = """
Problem: You are tasked with inventing a novel metaheuristic algorithm capable of minimizing an arbitrary real-valued, 
black-box, single-objective function defined over simple bound constraints.

Write a Python function that implements your algorithm. The function must take exactly these arguments:
- function: Callable[np.ndarray], float] - the objective function to minimise.
- bounds: list[tuple[float, float]] - a list of (lower, upper) pairs delimiting the search space for each dimension.
- budget: int - the total number of objective-function evaluations the algorithm may perform.

The function should return a tuple[float, np.ndarray] containing the best objective value found and the corresponding decision vector.

Your solution should be wrapped in a Markdown Python code block.

```python
import numpy as np 

def new_metaheuristic(
	function: Callable[[np.ndarray], float], 
    bounds: list[tuple[float, float]], 
    budget: int
) -> tuple[float, np.ndarray]:
    ...
```
"""

response = client.models.generate_content(model=MODEL, contents=[PROMPT_METAHEURISTIC])
print(response.text)
# Out:
# The proposed novel metaheuristic algorithm is called **Adaptive Thermal Swarm Optimization (ATSO)**.
#
# ATSO combines principles from Particle Swarm Optimization (PSO) and Simulated Annealing (SA) to navigate the search space. Unlike traditional PSO, it does not maintain an explicit velocity vector. Instead, particles directly propose new positions influenced by their personal best, the global best, and a random exploration component. The magnitude of these movements and the probability of accepting potentially worse solutions are dynamically controlled by a global "temperature" parameter that decreases over iterations, mimicking an annealing schedule. This mechanism allows ATSO to balance exploration (at high temperatures) and exploitation (at low temperatures) effectively.
#
# **Key Features of ATSO:**
#
# 1.  **Hybrid Movement Strategy**: Each particle's proposed movement is a blend of attraction towards its personal best position (`p_best`), attraction towards the global best position (`g_best`), and a stochastic exploration component.
# 2.  **Temperature-Controlled Step Size**: The overall magnitude of the proposed movement is directly scaled by the current temperature. Higher temperatures lead to larger steps, encouraging broader exploration, while lower temperatures lead to finer adjustments, promoting exploitation.
# 3.  **Simulated Annealing-Inspired Acceptance**: If a particle's new position is better than its current one, it is always accepted. If it's worse, it may still be accepted with a probability governed by the current temperature and the objective function difference. This allows the algorithm to escape local optima.
# 4.  **Absence of Explicit Velocity**: Unlike PSO, ATSO simplifies the particle dynamics by directly calculating new positions based on influences and temperature, without maintaining and updating a velocity vector.
# 5.  **Adaptive Population and Iteration Management**: The algorithm dynamically determines the number of particles and iterations based on the given budget, ensuring efficient use of function evaluations.
#
# **Algorithm Steps:**
#
# 1.  **Initialization**:
#     *   Determine the number of particles based on the problem's dimensionality and the total budget.
#     *   Randomly initialize a population of particles within the defined bounds.
#     *   Evaluate the objective function for each particle.
#     *   Initialize each particle's `p_best` to its current position and its objective value.
#     *   Identify the `g_best` (best position found across all particles) and its objective value.
#     *   Initialize a high `temperature (T_init)` and define a cooling schedule.
#
# 2.  **Main Loop (Iterations until budget exhausted)**:
#     *   **Cooling**: Decrease the global `temperature` according to an exponential cooling schedule.
#     *   For each particle:
#         *   **Propose Movement**: Calculate a `raw_direction_vector` by summing:
#             *   A random component scaled by the difference between `p_best` and `current_pos`.
#             *   A random component scaled by the difference between `g_best` and `current_pos`.
#             *   A purely random exploration component scaled by the overall search space range.
#         *   **Scale Step**: Normalize the `raw_direction_vector`. Scale this normalized vector by the current `temperature`, a `base_step_scale` (e.g., a fraction of the search space), and the `search_space_range`. This generates the `step_vector`.
#         *   **New Position**: Add the `step_vector` to the particle's `current_pos` to get `new_pos`.
#         *   **Boundary Handling**: Clamp `new_pos` to ensure it stays within the search bounds.
#         *   **Evaluation**: Evaluate `function(new_pos)`.
#         *   **Acceptance Criterion (SA-like)**:
#             *   If `new_pos` yields a better objective value than `current_pos`, accept `new_pos`. Update `p_best` and `g_best` if applicable.
#             *   If `new_pos` yields a worse objective value, accept it with a probability `exp(-delta_E / T)`, where `delta_E` is the increase in objective value. This allows escaping local optima, especially at higher temperatures.
#
# 3.  **Termination**: The loop continues until the `budget` for function evaluations is exhausted.
#
# 4.  **Return**: The `g_best_value` and `g_best_position` found throughout the search.
#
# ```python
# import numpy as np
# from typing import Callable
#
# def _clamp(position: np.ndarray, lower_bounds: np.ndarray, upper_bounds: np.ndarray) -> np.ndarray:
#     """Clamps a position vector within the given bounds."""
#     return np.maximum(lower_bounds, np.minimum(position, upper_bounds))
#
# def new_metaheuristic(
#     function: Callable[[np.ndarray], float],
#     bounds: list[tuple[float, float]],
#     budget: int
# ) -> tuple[float, np.ndarray]:
#     """
#     Adaptive Thermal Swarm Optimization (ATSO) for black-box function minimization.
#
#     ATSO combines concepts from Particle Swarm Optimization (PSO) and Simulated Annealing (SA).
#     Particles move towards their personal best and the global best, influenced by random components.
#     The step size and the probability of accepting worse solutions are controlled by a
#     decreasing 'temperature' parameter. There is no explicit velocity; movement is
#     directly proposed based on attraction and exploration forces, then scaled by temperature.
#
#     Args:
#         function: The objective function to minimise.
#         bounds: A list of (lower, upper) pairs delimiting the search space for each dimension.
#         budget: The total number of objective-function evaluations the algorithm may perform.
#
#     Returns:
#         A tuple containing the best objective value found and the corresponding decision vector.
#     """
#
#     N_dim = len(bounds)
#     lower_bounds = np.array([b[0] for b in bounds])
#     upper_bounds = np.array([b[1] for b in bounds])
#     search_space_range = upper_bounds - lower_bounds # Vector representing the range for each dimension
#
#     # --- Handle edge cases for budget ---
#     if budget <= 0:
#         # If budget is zero or negative, no evaluations are possible.
#         return np.inf, np.zeros(N_dim)
#
#     if budget == 1:
#         # If budget is 1, just evaluate one random point and return it.
#         initial_pos = np.random.uniform(lower_bounds, upper_bounds, size=N_dim)
#         obj_val = function(initial_pos)
#         return obj_val, initial_pos
#
#     # --- ATSO Parameters ---
#     T_init = 1.0  # Initial temperature (relative scale)
#     T_final = 1e-6 # Final temperature
#     base_step_scale = 0.05 # Base step size as a fraction of the search space range
#
#     # Determine number of particles dynamically based on dimensionality and budget
#     # Ensure N_particles allows for at least one iteration after initial evaluations
#     max_particles_allowed = budget - 1
#     N_particles = min(max_particles_allowed, max(1, int(10 + N_dim / 2)))
#
#     # If N_particles ends up being 0 due to very small budget (should be handled by budget <=1 case)
#     if N_particles < 1:
#         initial_pos = np.random.uniform(lower_bounds, upper_bounds, size=N_dim)
#         obj_val = function(initial_pos)
#         return obj_val, initial_pos
#
#     # --- Initialization ---
#     positions = np.random.uniform(lower_bounds, upper_bounds, size=(N_particles, N_dim))
#     eval_count = 0
#
#     objectives = np.zeros(N_particles)
#     for i in range(N_particles):
#         objectives[i] = function(positions[i])
#         eval_count += 1
#         if eval_count >= budget:
#             # If budget runs out during initialisation, return the best found so far
#             g_best_idx_partial = np.argmin(objectives[:i+1])
#             return objectives[g_best_idx_partial], positions[g_best_idx_partial]
#
#     p_best_positions = np.copy(positions)
#     p_best_objectives = np.copy(objectives)
#
#     g_best_index = np.argmin(p_best_objectives)
#     g_best_value = p_best_objectives[g_best_index]
#     g_best_position = p_best_positions[g_best_index].copy() # Store a copy to prevent mutation
#
#     # Calculate maximum number of iterations based on remaining budget
#     max_iterations = (budget - eval_count) // N_particles
#     if max_iterations <= 0:
#         # No budget left for full iterations, return best found during initialization
#         return g_best_value, g_best_position
#
#     # Cooling schedule: exponential decay to reach T_final in max_iterations
#     cooling_rate_alpha = (T_final / T_init) ** (1.0 / max_iterations)
#     current_T = T_init
#
#     # --- Main Optimization Loop ---
#     for _ in range(max_iterations):
#         current_T *= cooling_rate_alpha # Decrease temperature
#
#         for i in range(N_particles):
#             if eval_count >= budget:
#                 break # Break if budget exceeded mid-iteration
#
#             current_pos = positions[i]
#             current_obj = objectives[i]
#             p_best = p_best_positions[i]
#             g_best = g_best_position
#
#             # Generate random coefficients for attraction and exploration
#             r1 = np.random.uniform(0, 1, N_dim) # Personal best influence
#             r2 = np.random.uniform(0, 1, N_dim) # Global best influence
#             r_explore = np.random.uniform(-1, 1, N_dim) # Random exploration component (between -1 and 1)
#
#             # Combine influences to form a raw direction vector
#             personal_attraction = r1 * (p_best - current_pos)
#             global_attraction = r2 * (g_best - current_pos)
#             exploration_component = r_explore * search_space_range # Scaled by actual dimension range
#
#             raw_direction_vector = personal_attraction + global_attraction + exploration_component
#
#             # Normalize the direction vector and scale it by temperature and base step size
#             norm_direction = np.linalg.norm(raw_direction_vector)
#             if norm_direction > 1e-10: # Avoid division by zero or very small numbers
#                 normalized_direction = raw_direction_vector / norm_direction
#             else:
#                 # If direction vector is nearly zero, generate a small random unit vector
#                 normalized_direction = np.random.uniform(-1, 1, N_dim)
#                 normalized_direction /= np.linalg.norm(normalized_direction)
#
#             # Step magnitude controlled by temperature, base scale, and search space range
#             # T_init = 1.0 means at start, step_magnitude_factor is base_step_scale.
#             # It decreases with T, leading to smaller steps over time.
#             step_magnitude_factor = current_T * base_step_scale
#             step_vector = step_magnitude_factor * search_space_range * normalized_direction
#
#             new_pos = current_pos + step_vector
#             new_pos = _clamp(new_pos, lower_bounds, upper_bounds)
#
#             # Evaluate the new position
#             new_obj = function(new_pos)
#             eval_count += 1
#
#             # Decision: Accept new position based on SA-like criterion
#             delta_E = new_obj - current_obj
#
#             if delta_E < 0: # If the new position is better
#                 positions[i] = new_pos
#                 objectives[i] = new_obj
#                 # Update personal best if new_obj is better
#                 if new_obj < p_best_objectives[i]:
#                     p_best_positions[i] = new_pos
#                     p_best_objectives[i] = new_obj
#                 # Update global best if new_obj is better
#                 if new_obj < g_best_value:
#                     g_best_value = new_obj
#                     g_best_position = new_pos.copy() # Store a copy
#             else: # If new position is worse or equal, accept with a probability
#                 if current_T > T_final: # Only probabilistic acceptance if T is not too low
#                     acceptance_probability = np.exp(-delta_E / current_T)
#                     if np.random.rand() < acceptance_probability:
#                         positions[i] = new_pos
#                         objectives[i] = new_obj
#                 # If T is very low, or not accepted, particle stays at current_pos
#
#         if eval_count >= budget:
#             break # Break from outer loop if budget exceeded
#
#     return g_best_value, g_best_position
# ```

# %% [markdown]
# Parse it and benchmark on Rastrigin (10D, average over 10 seeds):

# %%
import random
from typing import Callable

import numpy as np


def rastrigin(x: np.ndarray) -> float:
    A: float = 10.0
    return float(A * len(x) + np.sum(x**2 - A * np.cos(2 * np.pi * x)))


class OptimizerVerifier:
    def __init__(
        self,
        budget: int = 10_000,
        dims: int = 10,
        seeds_count: int = 10,
        test_function: Callable = rastrigin,
    ) -> None:
        self.budget = budget
        self.dims = dims
        self.seeds_count = seeds_count
        self.test_function = test_function

    def verify(self, optimizer: Callable) -> float:
        bounds = [(-5, 5) for _ in range(self.dims)]
        results = []
        for seed in range(self.seeds_count):
            np.random.seed(seed)
            random.seed(seed)
            best_val, _ = optimizer(self.test_function, bounds, self.budget)
            results.append(best_val)
        return float(np.mean(results))


metaheuristic = FunctionParser.parse(response.text, "new_metaheuristic")
mean_score_for_rastrigin = OptimizerVerifier().verify(metaheuristic)
mean_score_for_rastrigin
# Out:
# 38.30026023230871

# %% [markdown]
# ### 3. Evolution of Heuristics
#
# Each generated metaheuristic has a measurable fitness (its score on the benchmark). That means we can apply crossover and mutation operators to *textual* solutions and run an evolutionary loop in the space of Python functions that represent optimization algorithms.
#
# ### Exercise 1
# Describe the meta‑heuristic generated by Gemini. Does the idea make sense? Is it novel? What are its weaknesses?

# %% [markdown]
# ATSO hybridizes PSO and Simulated Annealing by using temperature to control both step size and Metropolis acceptance, which is mechanistically sound but not novel — PSO–SA hybrids have been published since the early 2000s. The main weaknesses are that normalizing the direction vector discards distance-to-attractor information, the SA acceptance criterion is computed against the current position rather than p_best (creating inconsistent dynamics), and the global temperature schedule cannot adapt to individual particle landscapes. The base_step_scale = 0.05 magic constant also makes the algorithm brittle on non-isotropic problems.

# %% [markdown]
# ### Exercise 2
# Generate N = 5 distinct algorithms, benchmark them, and report the best.
#
# > **💡 Tip.** The underlying idea is simple: instead of trying to produce a single perfect algorithm, use the LLM as a generator that samples many different approaches. In practice, we could generate thousands of candidate algorithms and automatically evaluate them. Most of them will likely be poor, but that is acceptable — we only need a few strong candidates to discover an effective baseline. The key insight is that the LLM is valuable not just as a solver, but as a high-throughput source of diverse algorithmic ideas.
#
# ![monkeys](./monkeys.jpg)

# %%
best_score = float("inf")
best_response = None

for i in range(5):
    response = client.models.generate_content(model=MODEL, contents=[PROMPT_METAHEURISTIC])
    metaheuristic = FunctionParser.parse(response.text, "new_metaheuristic")
    if metaheuristic is None:
        continue
    score = OptimizerVerifier().verify(metaheuristic)
    print(f'Algorithm {i+1}: score: {score:.4f}')
    if score < best_score:
        best_score = score
        best_response = response.text

print(f'Best score: {best_score:.4f}')
print(f'Best response:\n{best_response}')
# Out:
# Algorithm 1: score: 46.4756
# Algorithm 2: score: 30.9090
# Algorithm 3: score: 45.3572
# Algorithm 4: score: 39.8980
# Algorithm 5: score: 20.2096
# Best score: 20.2096
# Best response:
# ```python
# import numpy as np
# from typing import Callable
#
# def new_metaheuristic(
#     function: Callable[[np.ndarray], float],
#     bounds: list[tuple[float, float]],
#     budget: int
# ) -> tuple[float, np.ndarray]:
#     """
#     Implements a novel metaheuristic algorithm called "Adaptive Neighborhood Search (ANS)"
#     for minimizing a black-box, real-valued, single-objective function within bound constraints.
#
#     The ANS algorithm maintains a population of "explorers," each with an adaptive search radius.
#     Explorers search their local neighborhood by generating candidate solutions. Successful
#     searches contract an explorer's radius to intensify exploitation of promising areas,
#     while unsuccessful searches expand the radius to promote broader exploration.
#     Stagnant explorers (those that repeatedly fail to improve) are reinitialized
#     to new random locations to escape local optima. The algorithm also balances
#     pure random exploration around an explorer with a tendency to move towards
#     the globally best-found solution, with this balance dynamically shifting
#     towards exploitation as the budget decreases.
#
#     Args:
#         function (Callable[[np.ndarray], float]): The objective function to minimize.
#                                                   It takes a 1D numpy array (decision vector)
#                                                   and returns a float (objective value).
#         bounds (list[tuple[float, float]]): A list of (lower, upper) pairs defining
#                                             the search space for each dimension.
#         budget (int): The total number of objective-function evaluations the algorithm
#                       is allowed to perform.
#
#     Returns:
#         tuple[float, np.ndarray]: A tuple containing the best objective value found
#                                   and the corresponding decision vector.
#     """
#
#     # --- Algorithm Parameters ---
#     D = len(bounds)
#     lower_bounds = np.array([b[0] for b in bounds])
#     upper_bounds = np.array([b[1] for b in bounds])
#
#     # Calculate maximum diagonal length of the search space for scaling radii
#     # This provides a sense of the "size" of the search space.
#     bounds_range = upper_bounds - lower_bounds
#     max_diag = np.sqrt(np.sum(np.square(bounds_range)))
#     if max_diag < 1e-9: # Handle cases where search space is a single point or D=0 (degenerate)
#         max_diag = 1.0 # Default to 1.0 to avoid division by zero or tiny radii
#
#     N = 10  # Number of explorers (population size)
#     k = 5   # Number of candidate points generated per explorer per iteration
#     initial_radius_factor = 0.2  # Initial radius as a fraction of max_diag
#     min_radius_factor = 1e-5     # Minimum radius factor to prevent tiny steps (relative to max_diag)
#     max_radius_factor = 1.0      # Maximum radius factor to prevent excessively large steps (relative to max_diag)
#     contraction_factor = 0.85    # Factor to contract radius upon success (e.g., 0.85 means radius becomes 85% of old)
#     expansion_factor = 1.15      # Factor to expand radius upon failure (e.g., 1.15 means radius becomes 115% of old)
#     stagnation_threshold = 10    # Number of iterations an explorer can fail before reinitialization
#     exploration_prob_initial = 0.8 # Initial probability of pure random search vs. directed search
#     exploration_prob_decay = 0.995 # Decay factor for exploration_prob per main iteration
#
#     # --- Handle very small budget gracefully ---
#     if budget <= 0:
#         return np.inf, np.zeros(D) # Return infinity and a zero vector for no budget
#
#     # If budget is too small for a full initial population, just sample one point
#     if budget < N:
#         x_init = np.random.uniform(low=lower_bounds, high=upper_bounds, size=D)
#         f_init = function(x_init)
#         return f_init, x_init
#
#     # --- 1. Initialization ---
#     explorers = np.random.uniform(low=lower_bounds, high=upper_bounds, size=(N, D))
#     explorer_fitness = np.array([function(x) for x in explorers])
#     budget -= N
#
#     explorer_radii = np.full(N, initial_radius_factor * max_diag)
#     stagnation_counters = np.zeros(N, dtype=int)
#
#     best_idx = np.argmin(explorer_fitness)
#     x_best = explorers[best_idx].copy()
#     f_best = explorer_fitness[best_idx]
#
#     exploration_prob = exploration_prob_initial
#
#     # --- 2. Main Loop ---
#     # The loop continues as long as there is budget left for at least one candidate evaluation.
#     while budget > 0:
#
#         # Shuffle explorer indices to ensure each explorer gets a chance and to prevent bias
#         shuffled_indices = np.random.permutation(N)
#
#         for i_idx in range(N):
#             if budget <= 0: # Check if budget exhausted after previous explorer's operations
#                 break
#
#             i = shuffled_indices[i_idx] # Current explorer index
#             x_current = explorers[i].copy()
#             f_current = explorer_fitness[i]
#             r_current = explorer_radii[i]
#
#             # Determine how many candidates we can actually evaluate for this explorer
#             actual_k = min(k, budget)
#             if actual_k == 0:
#                 break # Not enough budget for even one candidate for this explorer, move to next or exit.
#
#             candidates = []
#             for j in range(actual_k):
#                 # Determine a random direction for perturbation
#                 perturbation_direction = np.random.uniform(-1, 1, D)
#                 # Normalize perturbation_direction to a unit vector; add epsilon to avoid division by zero
#                 norm_pd = np.linalg.norm(perturbation_direction)
#                 if norm_pd > 1e-10:
#                     perturbation_direction /= norm_pd
#                 else: # If perturbation_direction is a zero vector (highly unlikely), use a random unit vector
#                     perturbation_direction = np.random.randn(D)
#                     perturbation_direction /= (np.linalg.norm(perturbation_direction) + 1e-10)
#
#                 step_magnitude = r_current * np.random.rand() # Step size within the current explorer's radius
#
#                 new_point = x_current.copy()
#                 if np.random.rand() < exploration_prob: # Exploration phase: purely random walk around current point
#                     new_point += perturbation_direction * step_magnitude
#                 else: # Exploitation phase: move towards global best, plus a smaller perturbation for local search
#                     dir_to_best = x_best - x_current
#                     move_factor = np.random.rand() # Move a random fraction towards x_best
#                     # Add a smaller perturbation to maintain some local exploration
#                     new_point += dir_to_best * move_factor + perturbation_direction * (step_magnitude * 0.1)
#
#                 # Boundary Handling: Clip the new point to stay within defined bounds
#                 new_point = np.clip(new_point, lower_bounds, upper_bounds)
#                 candidates.append(new_point)
#
#             # Evaluate generated candidates and update budget
#             current_candidates_evals = []
#             for p in candidates:
#                 if budget <= 0: # Ensure budget isn't exceeded during candidate evaluations
#                     break
#                 f_p = function(p)
#                 current_candidates_evals.append((f_p, p))
#                 budget -= 1
#
#             if not current_candidates_evals: # If budget ran out while evaluating candidates, break
#                 break
#
#             # Find the best candidate among those evaluated
#             current_candidates_evals.sort(key=lambda x: x[0])
#             f_new, x_new = current_candidates_evals[0]
#
#             # --- 2.2 Update Explorer State ---
#             if f_new < f_current: # Improvement found for the current explorer
#                 explorers[i] = x_new
#                 explorer_fitness[i] = f_new
#                 # Contract radius, ensuring it doesn't go below the minimum allowed radius
#                 explorer_radii[i] = max(min_radius_factor * max_diag, explorer_radii[i] * contraction_factor)
#                 stagnation_counters[i] = 0 # Reset stagnation counter
#             else: # No improvement for the current explorer
#                 stagnation_counters[i] += 1
#                 # Expand radius, ensuring it doesn't exceed the maximum allowed radius
#                 explorer_radii[i] = min(max_radius_factor * max_diag, explorer_radii[i] * expansion_factor)
#
#                 if stagnation_counters[i] >= stagnation_threshold:
#                     # Explorer has stagnated, reinitialize to a new random location
#                     explorers[i] = np.random.uniform(low=lower_bounds, high=upper_bounds, size=D)
#                     if budget <= 0: # Check budget before re-evaluating the reinitialized explorer
#                         break
#                     explorer_fitness[i] = function(explorers[i])
#                     budget -= 1
#                     explorer_radii[i] = initial_radius_factor * max_diag # Reset radius to initial value
#                     stagnation_counters[i] = 0 # Reset stagnation counter
#
#             # --- 2.3 Global Best Update ---
#             # If the current explorer's best fitness is better than the global best
#             if explorer_fitness[i] < f_best:
#                 f_best = explorer_fitness[i]
#                 x_best = explorers[i].copy()
#
#         # Decay exploration probability for the next main iteration.
#         # This shifts the algorithm's focus from exploration to exploitation over time.
#         exploration_prob = max(0.1, exploration_prob * exploration_prob_decay)
#
#     return f_best, x_best
# ```

# %% [markdown]
# ### Exercise 3
# Review [Evolution of Heuristics: Towards Efficient Automatic Algorithm Design Using Large Language Model](https://arxiv.org/pdf/2401.02051) and read **3.4 Prompt Strategies**. Re-implement one of the prompt strategies (M1, M2, or M3). For reference, here's the [GitHub repository](https://github.com/FeiLiu36/EoH) and here's the key [file](https://github.com/FeiLiu36/EoH/blob/main/eoh/src/eoh/methods/eoh/eoh_evolution.py) with all prompts.

# %% [markdown]
# <details><summary><b>Hint 1</b></summary><br>Read <code>get_prompt_m2</code> method and adapt it to our case (signature of the function is slightly different, but the idea is the same).</details>
#
#
# <details><summary><b>Hint 2</b></summary><br>The core idea behind M2 is: "Please identify the main algorithm parameters and assist me in creating a new algorithm with different parameter settings for the provided score function." We should incorporate this instruction directly into the prompt together with the generated metaheuristic.</details>
#
#
# <details><summary><b>Comment</b></summary><br>In the paper they describe it as "M2: Modify the parameters of one selected heuristic. First, one heuristic is selected from the current population. Then, LLM is prompted to try different parameters in the current heuristic instead of designing a new one." In practice, though, the idea is extremely simple.</details>
#
#
# <details><summary><b>Hint 3</b></summary><br>Use a prompt like this:<pre>I have one algorithm with its code as follows.
# ```python
# {metaheuristic}
# ```
# Please identify the main algorithm parameters and assist me in creating a new algorithm that has a different parameter settings.
# Write a Python function that implements your algorithm. The function must take exactly these arguments:
# - function: Callable[np.ndarray], float] - the objective function to minimise.
# - bounds: list[tuple[float, float]] - a list of (lower, upper) pairs delimiting the search space for each dimension.
# - budget: int - the total number of objective-function evaluations the algorithm may perform.
# The function should return a tuple[float, np.ndarray] containing the best objective value found and the corresponding decision vector.
# Your solution should be wrapped in a Markdown Python code block.
# ```python
# import numpy as np
# def new_metaheuristic(
#     function: Callable[[np.ndarray], float],
#     bounds: list[tuple[float, float]],
#     budget: int
# ) -> tuple[float, np.ndarray]:
#     ...
# ```
# Do not give additional explanations.</pre></details>

# %%
PROMPT_METAHEURISTIC_M2 = f"""
I have one algorithm with its code as follows.
{best_response}
Please identify the main algorithm parameters and assist me in creating a new algorithm that has a different parameter settings.
Write a Python function that implements your algorithm. The function must take exactly these arguments:
- function: Callable[np.ndarray], float] - the objective function to minimise.
- bounds: list[tuple[float, float]] - a list of (lower, upper) pairs delimiting the search space for each dimension.
- budget: int - the total number of objective-function evaluations the algorithm may perform.
The function should return a tuple[float, np.ndarray] containing the best objective value found and the corresponding decision vector.
Your solution should be wrapped in a Markdown Python code block.
```python
import numpy as np
def new_metaheuristic(
    function: Callable[[np.ndarray], float],
    bounds: list[tuple[float, float]],
    budget: int
) -> tuple[float, np.ndarray]:
    ...
```
Do not give additional explanations.
"""
best_response_m2 = None
best_score_m2 = float("inf")

for i in range(5):

    response_m2 = client.models.generate_content(model=MODEL, contents=[PROMPT_METAHEURISTIC_M2])
    metaheuristic_m2 = FunctionParser.parse(response_m2.text, "new_metaheuristic")
    score_m2 = OptimizerVerifier().verify(metaheuristic_m2)
    print(f'Score for Algorithm {i+1} with M2:{score_m2:.4f}')

    if score_m2 < best_score_m2:
        best_score_m2 = score_m2
        best_response_m2 = response_m2.text
print(f"Best Response for M2: {best_response_m2}")
# Out:
# Score for Algorithm 1 with M2:26.9656
# Score for Algorithm 2 with M2:12.0206
# Score for Algorithm 3 with M2:11.7405
# Score for Algorithm 4 with M2:25.4709
# Score for Algorithm 5 with M2:22.5141
# Best Response for M2: ```python
# import numpy as np
# from typing import Callable
#
# def new_metaheuristic(
#     function: Callable[[np.ndarray], float],
#     bounds: list[tuple[float, float]],
#     budget: int
# ) -> tuple[float, np.ndarray]:
#     """
#     Implements the "Differential Evolution with Global-Best Mutation (DE-GBM)" algorithm.
#
#     This algorithm follows a population-based evolutionary strategy. Unlike the
#     Adaptive Neighborhood Search which uses local radii, DE-GBM utilizes the
#     distribution of the population itself to determine search steps.
#
#     Key Parameters:
#     - pop_size (N): 20 (The size of the population)
#     - F (Scaling Factor): 0.5 (Controls the magnitude of differential variations)
#     - CR (Crossover Rate): 0.7 (Probability of inheriting components from the mutant)
#     - Strategy: DE/best/1/bin (Uses the best individual to guide mutation for faster convergence)
#     """
#
#     # --- Algorithm Parameters ---
#     D = len(bounds)
#     lower_bounds = np.array([b[0] for b in bounds])
#     upper_bounds = np.array([b[1] for b in bounds])
#
#     # Population size should be at least 4 for the logic,
#     # but we handle lower budgets gracefully.
#     pop_size = 20
#     F = 0.5
#     CR = 0.7
#
#     if budget <= 0:
#         return np.inf, np.zeros(D)
#
#     # --- 1. Initialization ---
#     # Handle small budget cases
#     if budget < pop_size:
#         x_best = np.random.uniform(lower_bounds, upper_bounds, D)
#         f_best = function(x_best)
#         budget -= 1
#         while budget > 0:
#             x_new = np.random.uniform(lower_bounds, upper_bounds, D)
#             f_new = function(x_new)
#             if f_new < f_best:
#                 f_best, x_best = f_new, x_new
#             budget -= 1
#         return f_best, x_best
#
#     # Initialize population and evaluate fitness
#     population = np.random.uniform(lower_bounds, upper_bounds, (pop_size, D))
#     fitness = np.zeros(pop_size)
#     for i in range(pop_size):
#         fitness[i] = function(population[i])
#         budget -= 1
#
#     # Identify the initial best
#     best_idx = np.argmin(fitness)
#     f_best = fitness[best_idx]
#     x_best = population[best_idx].copy()
#
#     # --- 2. Main Loop ---
#     while budget > 0:
#         for i in range(pop_size):
#             if budget <= 0:
#                 break
#
#             # Selection of two distinct individuals for the differential
#             # Using DE/best/1 strategy (x_best + F * (x_r1 - x_r2))
#             available_indices = [idx for idx in range(pop_size) if idx != i]
#             r1, r2 = np.random.choice(available_indices, 2, replace=False)
#
#             # --- 2.1 Mutation ---
#             # Create a mutant vector based on the global best
#             mutant = x_best + F * (population[r1] - population[r2])
#
#             # Boundary Handling: Clip mutant to search space
#             mutant = np.clip(mutant, lower_bounds, upper_bounds)
#
#             # --- 2.2 Crossover ---
#             # Binomial crossover to create trial vector
#             cross_mask = np.random.rand(D) < CR
#             # Ensure at least one component is taken from the mutant
#             if not np.any(cross_mask):
#                 cross_mask[np.random.randint(0, D)] = True
#
#             trial_vector = np.where(cross_mask, mutant, population[i])
#
#             # --- 2.3 Selection ---
#             f_trial = function(trial_vector)
#             budget -= 1
#
#             # If the trial vector is better or equal, replace the individual
#             if f_trial <= fitness[i]:
#                 population[i] = trial_vector
#                 fitness[i] = f_trial
#
#                 # Update the global best found so far
#                 if f_trial < f_best:
#                     f_best = f_trial
#                     x_best = trial_vector.copy()
#
#     return f_best, x_best
# ```

# %% [markdown]
# Is the mutated algorithm better than the original one? How different is it from the original? Experiment with modifying the prompt and observe how the generated algorithm changes. Can you obtain a significant improvement over the original metaheuristic?

# %% [markdown]
# Is the mutated algorithm better than the original? Yes — the best M2 variant scored 11.74 vs 20.21 for the original ANS, a ~42% improvement. Notably, M2 on Algorithm 3 didn't just tune parameters — it generated a structurally different algorithm (DE/best/1/bin instead of ANS), showing that M2 can trigger larger architectural shifts.
# How different is it from the original? It varies. Some M2 results (Algorithms 1, 4, 5) were just parameter-tuned ANS variants and performed worse or similarly. The best result (Algorithm 3) was a completely different algorithm — DE with global-best mutation — suggesting the LLM sometimes uses parameter-modification as a prompt to redesign the whole approach.
# Can you obtain a significant improvement? Yes — ~42% improvement over the original metaheuristic by running M2 five times and taking the best. The key insight is that M2 acts as a stochastic operator: most outputs are marginal tweaks, but occasionally it generates something structurally better. Running more iterations would likely yield further gains.

# %% [markdown]
# ### Exercise 3:
# Implement Evolution of Heuristics (or at least part of it). Start simple (pseudocode):
# ```
# current_population = [generate_heuristic()]
# for _ in range(10):
#    parent = current_population[-1]
#    new_solution = M2(parent)
#    f_new_solution = verify(new_solution)
#    current_population.append(new_solution)
# ```
# Save all generated solutions, preferably using a separate file for each one. Analyse the generated algorithms and identify the most common ideas or design patterns. Plot the solution quality across epochs and investigate whether the iterative process exhibits convergence.

# %%
import os
import matplotlib.pyplot as plt

os.makedirs("generated_algorithms", exist_ok=True)

verifier = OptimizerVerifier()

def get_m2_prompt(code: str) -> str:
    return f"""I have one algorithm with its code as follows.
```python
{code}
```
Please identify the main algorithm parameters and assist me in creating a new algorithm that has different parameter settings.
Write a Python function that implements your algorithm. The function must take exactly these arguments:
- function: Callable[np.ndarray], float] - the objective function to minimise.
- bounds: list[tuple[float, float]] - a list of (lower, upper) pairs delimiting the search space for each dimension.
- budget: int - the total number of objective-function evaluations the algorithm may perform.
The function should return a tuple[float, np.ndarray] containing the best objective value found and the corresponding decision vector.
Your solution should be wrapped in a Markdown Python code block.
```python
import numpy as np
def new_metaheuristic(
    function: Callable[[np.ndarray], float],
    bounds: list[tuple[float, float]],
    budget: int
) -> tuple[float, np.ndarray]:
    ...
```
Do not give additional explanations."""


current_code = FunctionParser.extract_code(best_response_m2)
current_score = best_score_m2

scores = [current_score]
population = [(current_score, current_code)]

print(f"Starting score (best M2 from Ex2): {current_score:.4f}")

for epoch in range(10):
    response = client.models.generate_content(model=MODEL, contents=[get_m2_prompt(current_code)])
    new_code = FunctionParser.extract_code(response.text)
    new_fn = FunctionParser.parse(response.text, "new_metaheuristic")

    if new_fn is None or new_code is None:
        print(f"Epoch {epoch + 1}: parse failed, keeping current")
        scores.append(current_score)
        continue

    new_score = verifier.verify(new_fn)
    print(f"Epoch {epoch + 1}: score = {new_score:.4f}")

    with open(f"generated_algorithms/epoch_{epoch + 1}.py", "w") as f:
        f.write(new_code)

    scores.append(new_score)
    population.append((new_score, new_code))
    current_code = new_code
    current_score = new_score

best_score_eoh, best_code_eoh = min(population, key=lambda x: x[0])
print(f"\nBest score across all epochs: {best_score_eoh:.4f}")

plt.figure(figsize=(8, 4))
plt.plot(scores, marker="o")
plt.xlabel("Epoch")
plt.ylabel("Mean best fitness (10D Rastrigin)")
plt.title("Evolution of Heuristics — convergence")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Starting score (best M2 from Ex2): 11.7405
# Epoch 1: score = 13.9755
# Epoch 2: score = 11.7405
# Epoch 3: score = 23.1080
# Epoch 4: score = 15.8198
# Epoch 5: score = 8.5836
# Epoch 6: score = 18.9042
# Epoch 7: score = 0.1991
# Epoch 8: score = 31.7391
# Epoch 9: score = 34.5231
# Epoch 10: score = 15.8198
#
# Best score across all epochs: 0.1991

# %% [markdown]
# ### 4. Recommended Reading
# - [AlphaEvolve: A Gemini-powered coding agent for designing advanced algorithms](https://deepmind.google/discover/blog/alphaevolve-a-gemini-powered-coding-agent-for-designing-advanced-algorithms/)
# - Shojaee, Parshin, et al. [LLM-SR: Scientific equation discovery via programming with large language models.](https://arxiv.org/abs/2404.18400)
# - Romera-Paredes, Bernardino, et al. [Mathematical discoveries from program search with large language models.](https://www.nature.com/articles/s41586-023-06924-6)
# - van Stein, Niki, and Thomas Bäck. [Llamea: A large language model evolutionary algorithm for automatically generating metaheuristics.](https://arxiv.org/abs/2405.20132)
# - Liu, Fei, et al. [Evolution of heuristics: Towards efficient automatic algorithm design using large language model.](https://arxiv.org/abs/2401.02051)
# - van Stein, Niki, et al. [BLADE: Benchmark suite for LLM-driven Automated Design and Evolution of iterative optimisation heuristics](https://arxiv.org/html/2504.20183v1)
# - [OpenEvolve](https://github.com/codelion/openevolve)
